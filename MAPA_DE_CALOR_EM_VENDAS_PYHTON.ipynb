# %% [markdown]
# # Graficos de mapas com python - mineirando dados ###

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.17.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from folium) (2024.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.7.4)

# %%
import folium

# %% [markdown]
# ## Renderizando meu primeiro Mapa

# %%
mapa = folium.Map(location=[-23.5025, -46.8978], zoom_start=12) #coloquei a localizacao na variavel mapa

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c5164b58f8856e436b83f42b944fd98 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c5164b58f8856e436b83f42b944fd98&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c5164b58f8856e436b83f42b944fd98 = L.map(
#                 &quot;map_2c5164b58f8856e436b83f42b944fd98&quot;,
#                 {
#                     center: [-23.5025, -46.8978],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f21f582d50316ef9ab5f3a4ec85221e7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f21f582d50316ef9ab5f3a4ec85221e7.addTo(map_2c5164b58f8856e436b83f42b944fd98);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Especificando diferentes Estilos.

# %%
folium.Map(
    location=[-23.5025, -46.8978],  # Coordenadas de BARUERI
    tiles='CartoDB dark_matter',    # Estilo dos mapas
    zoom_start=13                    # Nível de zoom
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_58c64f6a43f0f90190ce021d0b783b17 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_58c64f6a43f0f90190ce021d0b783b17&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_58c64f6a43f0f90190ce021d0b783b17 = L.map(
#                 &quot;map_58c64f6a43f0f90190ce021d0b783b17&quot;,
#                 {
#                     center: [-23.5025, -46.8978],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7963216e2d5a97e92ebba0e986fba571 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7963216e2d5a97e92ebba0e986fba571.addTo(map_58c64f6a43f0f90190ce021d0b783b17);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Diferenciando niveis de zoom

# %%
folium.Map(
    location=[-23.5025, -46.8978],  # Coordenadas de BARUERI
    tiles='CartoDB dark_matter',
    zoom_start=3     #Personalizar os niveis de zoom por aqui
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_99050f2079c5456b21006d1d32b583fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_99050f2079c5456b21006d1d32b583fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_99050f2079c5456b21006d1d32b583fb = L.map(
#                 &quot;map_99050f2079c5456b21006d1d32b583fb&quot;,
#                 {
#                     center: [-23.5025, -46.8978],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d432f2688347ed1d7980791283a981c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3d432f2688347ed1d7980791283a981c.addTo(map_99050f2079c5456b21006d1d32b583fb);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Adicionando Marcadores

# %%
mapa = folium.Map(
    location=[-23.5025, -46.8978],
    tiles='CartoDB positron',
    zoom_start=13
)

# %%
folium.Marker(
    location=[-23.495598, -46.848569],
    popup='<i>Alphaville</i>',  # Texto exibido ao clicar no marcador
    tooltip='Clique aqui!'      # Texto exibido ao passar o mouse sobre o marcador
).add_to(mapa)

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_884af278923540c157c305803e1be444 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_884af278923540c157c305803e1be444&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_884af278923540c157c305803e1be444 = L.map(
#                 &quot;map_884af278923540c157c305803e1be444&quot;,
#                 {
#                     center: [-23.5025, -46.8978],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_06b36a6fc692cd2f990530066cc8a2bc = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_06b36a6fc692cd2f990530066cc8a2bc.addTo(map_884af278923540c157c305803e1be444);
#
#
#             var marker_8c2e56db84e205a19b7caf7a389837b8 = L.marker(
#                 [-23.495598, -46.848569],
#                 {}
#             ).addTo(map_884af278923540c157c305803e1be444);
#
#
#         var popup_d098cd6a162172ee898df7bd24d1afde = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_827082517cb9f43cca1fb074a954760f = $(`&lt;div id=&quot;html_827082517cb9f43cca1fb074a954760f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Alphaville&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_d098cd6a162172ee898df7bd24d1afde.setContent(html_827082517cb9f43cca1fb074a954760f);
#
#
#
#         marker_8c2e56db84e205a19b7caf7a389837b8.bindPopup(popup_d098cd6a162172ee898df7bd24d1afde)
#         ;
#
#
#
#
#             marker_8c2e56db84e205a19b7caf7a389837b8.bindTooltip(
#                 `&lt;div&gt;
#                      Clique aqui!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Deixando os ponteiros de marcaçao verde

# %%
folium.Marker(
    location=[-23.495598, -46.848569],  # Coordenadas do marcador
    popup='<i>Alphaville</i>',           # Texto exibido ao clicar no marcador
    tooltip='Clique aqui!',              # Texto exibido ao passar o mouse sobre o marcador
    icon=folium.Icon(color='green')      # Cor do ícone
).add_to(mapa)

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_884af278923540c157c305803e1be444 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_884af278923540c157c305803e1be444&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_884af278923540c157c305803e1be444 = L.map(
#                 &quot;map_884af278923540c157c305803e1be444&quot;,
#                 {
#                     center: [-23.5025, -46.8978],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_06b36a6fc692cd2f990530066cc8a2bc = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_06b36a6fc692cd2f990530066cc8a2bc.addTo(map_884af278923540c157c305803e1be444);
#
#
#             var marker_8c2e56db84e205a19b7caf7a389837b8 = L.marker(
#                 [-23.495598, -46.848569],
#                 {}
#             ).addTo(map_884af278923540c157c305803e1be444);
#
#
#         var popup_d098cd6a162172ee898df7bd24d1afde = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_827082517cb9f43cca1fb074a954760f = $(`&lt;div id=&quot;html_827082517cb9f43cca1fb074a954760f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Alphaville&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_d098cd6a162172ee898df7bd24d1afde.setContent(html_827082517cb9f43cca1fb074a954760f);
#
#
#
#         marker_8c2e56db84e205a19b7caf7a389837b8.bindPopup(popup_d098cd6a162172ee898df7bd24d1afde)
#         ;
#
#
#
#
#             marker_8c2e56db84e205a19b7caf7a389837b8.bindTooltip(
#                 `&lt;div&gt;
#                      Clique aqui!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_06b36a6fc692cd2f990530066cc8a2bc.addTo(map_884af278923540c157c305803e1be444);
#
#
#             var marker_07e7d5d30ab83f13a7b263a8cf458f10 = L.marker(
#                 [-23.495598, -46.848569],
#                 {}
#             ).addTo(map_884af278923540c157c305803e1be444);
#
#
#             var icon_d37422c7e7c8f50f48d76b84536d6b01 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_07e7d5d30ab83f13a7b263a8cf458f10.setIcon(icon_d37422c7e7c8f50f48d76b84536d6b01);
#
#
#         var popup_15289f2befd7bec1c5cd4e3062529808 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3e5d9d31e3a5d3fbc2a05d33450325f8 = $(`&lt;div id=&quot;html_3e5d9d31e3a5d3fbc2a05d33450325f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Alphaville&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_15289f2befd7bec1c5cd4e3062529808.setContent(html_3e5d9d31e3a5d3fbc2a05d33450325f8);
#
#
#
#         marker_07e7d5d30ab83f13a7b263a8cf458f10.bindPopup(popup_15289f2befd7bec1c5cd4e3062529808)
#         ;
#
#
#
#
#             marker_07e7d5d30ab83f13a7b263a8cf458f10.bindTooltip(
#                 `&lt;div&gt;
#                      Clique aqui!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##Colocando circulo para marcar no mapa

# %%
folium.CircleMarker(
    location=[-23.495598, -46.848569],  # Coordenadas do marcador
    radius=50,                          # Raio do círculo em pixels
    color='#3186cc',                    # Cor da borda do círculo
    fill=True,                          # Preencher o círculo com cor
    fill_color='#3186cc'                # Cor de preenchimento do círculo
).add_to(mapa)

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_884af278923540c157c305803e1be444 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_884af278923540c157c305803e1be444&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_884af278923540c157c305803e1be444 = L.map(
#                 &quot;map_884af278923540c157c305803e1be444&quot;,
#                 {
#                     center: [-23.5025, -46.8978],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_06b36a6fc692cd2f990530066cc8a2bc = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_06b36a6fc692cd2f990530066cc8a2bc.addTo(map_884af278923540c157c305803e1be444);
#
#
#             var marker_8c2e56db84e205a19b7caf7a389837b8 = L.marker(
#                 [-23.495598, -46.848569],
#                 {}
#             ).addTo(map_884af278923540c157c305803e1be444);
#
#
#         var popup_d098cd6a162172ee898df7bd24d1afde = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_827082517cb9f43cca1fb074a954760f = $(`&lt;div id=&quot;html_827082517cb9f43cca1fb074a954760f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Alphaville&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_d098cd6a162172ee898df7bd24d1afde.setContent(html_827082517cb9f43cca1fb074a954760f);
#
#
#
#         marker_8c2e56db84e205a19b7caf7a389837b8.bindPopup(popup_d098cd6a162172ee898df7bd24d1afde)
#         ;
#
#
#
#
#             marker_8c2e56db84e205a19b7caf7a389837b8.bindTooltip(
#                 `&lt;div&gt;
#                      Clique aqui!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_06b36a6fc692cd2f990530066cc8a2bc.addTo(map_884af278923540c157c305803e1be444);
#
#
#             var marker_07e7d5d30ab83f13a7b263a8cf458f10 = L.marker(
#                 [-23.495598, -46.848569],
#                 {}
#             ).addTo(map_884af278923540c157c305803e1be444);
#
#
#             var icon_d37422c7e7c8f50f48d76b84536d6b01 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_07e7d5d30ab83f13a7b263a8cf458f10.setIcon(icon_d37422c7e7c8f50f48d76b84536d6b01);
#
#
#         var popup_15289f2befd7bec1c5cd4e3062529808 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3e5d9d31e3a5d3fbc2a05d33450325f8 = $(`&lt;div id=&quot;html_3e5d9d31e3a5d3fbc2a05d33450325f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Alphaville&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_15289f2befd7bec1c5cd4e3062529808.setContent(html_3e5d9d31e3a5d3fbc2a05d33450325f8);
#
#
#
#         marker_07e7d5d30ab83f13a7b263a8cf458f10.bindPopup(popup_15289f2befd7bec1c5cd4e3062529808)
#         ;
#
#
#
#
#             marker_07e7d5d30ab83f13a7b263a8cf458f10.bindTooltip(
#                 `&lt;div&gt;
#                      Clique aqui!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_06b36a6fc692cd2f990530066cc8a2bc.addTo(map_884af278923540c157c305803e1be444);
#
#
#             var circle_marker_5d93571edb3ddbdaa77c59a926be84c7 = L.circleMarker(
#                 [-23.495598, -46.848569],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_884af278923540c157c305803e1be444);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
##Exibindo as coordenadas de Latitude e Longitude no evento

# %%
mapa.add_child(folium.LatLngPopup())
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_884af278923540c157c305803e1be444 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_884af278923540c157c305803e1be444&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_884af278923540c157c305803e1be444 = L.map(
#                 &quot;map_884af278923540c157c305803e1be444&quot;,
#                 {
#                     center: [-23.5025, -46.8978],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_06b36a6fc692cd2f990530066cc8a2bc = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_06b36a6fc692cd2f990530066cc8a2bc.addTo(map_884af278923540c157c305803e1be444);
#
#
#             var marker_8c2e56db84e205a19b7caf7a389837b8 = L.marker(
#                 [-23.495598, -46.848569],
#                 {}
#             ).addTo(map_884af278923540c157c305803e1be444);
#
#
#         var popup_d098cd6a162172ee898df7bd24d1afde = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_827082517cb9f43cca1fb074a954760f = $(`&lt;div id=&quot;html_827082517cb9f43cca1fb074a954760f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Alphaville&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_d098cd6a162172ee898df7bd24d1afde.setContent(html_827082517cb9f43cca1fb074a954760f);
#
#
#
#         marker_8c2e56db84e205a19b7caf7a389837b8.bindPopup(popup_d098cd6a162172ee898df7bd24d1afde)
#         ;
#
#
#
#
#             marker_8c2e56db84e205a19b7caf7a389837b8.bindTooltip(
#                 `&lt;div&gt;
#                      Clique aqui!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_06b36a6fc692cd2f990530066cc8a2bc.addTo(map_884af278923540c157c305803e1be444);
#
#
#             var marker_07e7d5d30ab83f13a7b263a8cf458f10 = L.marker(
#                 [-23.495598, -46.848569],
#                 {}
#             ).addTo(map_884af278923540c157c305803e1be444);
#
#
#             var icon_d37422c7e7c8f50f48d76b84536d6b01 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_07e7d5d30ab83f13a7b263a8cf458f10.setIcon(icon_d37422c7e7c8f50f48d76b84536d6b01);
#
#
#         var popup_15289f2befd7bec1c5cd4e3062529808 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3e5d9d31e3a5d3fbc2a05d33450325f8 = $(`&lt;div id=&quot;html_3e5d9d31e3a5d3fbc2a05d33450325f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Alphaville&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_15289f2befd7bec1c5cd4e3062529808.setContent(html_3e5d9d31e3a5d3fbc2a05d33450325f8);
#
#
#
#         marker_07e7d5d30ab83f13a7b263a8cf458f10.bindPopup(popup_15289f2befd7bec1c5cd4e3062529808)
#         ;
#
#
#
#
#             marker_07e7d5d30ab83f13a7b263a8cf458f10.bindTooltip(
#                 `&lt;div&gt;
#                      Clique aqui!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_06b36a6fc692cd2f990530066cc8a2bc.addTo(map_884af278923540c157c305803e1be444);
#
#
#             var circle_marker_5d93571edb3ddbdaa77c59a926be84c7 = L.circleMarker(
#                 [-23.495598, -46.848569],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_884af278923540c157c305803e1be444);
#
#
#             tile_layer_06b36a6fc692cd2f990530066cc8a2bc.addTo(map_884af278923540c157c305803e1be444);
#
#
#                 var lat_lng_popup_7e9f300ec5aff59570ca5644bc2d9e42 = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_7e9f300ec5aff59570ca5644bc2d9e42
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_884af278923540c157c305803e1be444);

# %% [markdown]
# # Fazendo o mapa de calor das vendas em cada região do mapa

# %%
import pandas as pd
from folium import plugins
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/COLAB PROJECTS/olist_geolocation_dataset.csv")

# %%
df.info() #informacoes da base de dados .
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
coordenadas = []

for lat, lng in zip(df.geolocation_lat.values[:18000], df.geolocation_lng.values[:18000]): #pegando os primeiros 18mil registros
    coordenadas.append([lat, lng])

# %%
mapa = folium.Map(location=[-15.788497, -47.879873],zoom_start=5,tiles='CartoDB dark_matter')
# Coordenadas centrais do mapa
 # Nível inicial de zoom
  # Estilo dos tiles

# %%
mapa.add_child(plugins.HeatMap(coordenadas))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e8ff471b4d844689ba5b50e278b1a9b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e8ff471b4d844689ba5b50e278b1a9b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e8ff471b4d844689ba5b50e278b1a9b6 = L.map(
#                 &quot;map_e8ff471b4d844689ba5b50e278b1a9b6&quot;,
#                 {
#                     center: [-15.788497, -47.879873],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1181faebbf5dec5bb2814b497ae9e122 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1181faebbf5dec5bb2814b497ae9e122.addTo(map_e8ff471b4d844689ba5b50e278b1a9b6);
#
#
#             var heat_map_e55715735f664b1e0abdff5dd80a5426 = L.heatLayer(
#                 [[-23.54562128115268, -46.63929204800168], [-23.54608112703553, -46.64482029837157], [-23.54612896641469, -46.64295148361138], [-23.5443921648681, -46.63949930627844], [-23.541577961711493, -46.64160722329613], [-23.547762303364262, -46.63536053788448], [-23.54627311241268, -46.64122516971552], [-23.546923208436723, -46.6342636964915], [-23.543769055769133, -46.63427784085132], [-23.547639550320632, -46.63603162315495], [-23.547325128224376, -46.63418378613892], [-23.53841810407414, -46.634778375266734], [-23.546435343326205, -46.63383023397196], [-23.548945985189437, -46.63467113292871], [-23.54518734081604, -46.63785524104107], [-23.54608112703553, -46.64482029837157], [-23.54188300998332, -46.63991946670314], [-23.541389521053937, -46.62989908781218], [-23.54693540437998, -46.63658792659698], [-23.54588427921401, -46.64316319124004], [-23.545165891770928, -46.643785796266464], [-23.55223547100232, -46.6284406588955], [-23.546690486964888, -46.6354469588072], [-23.546656718016017, -46.64078762115524], [-23.549773516504185, -46.64559900666509], [-23.541593762969622, -46.64189378810082], [-23.545429533441077, -46.63571531432852], [-23.550392524842728, -46.63730164071784], [-23.5398418758395, -46.63514797691531], [-23.543539449073783, -46.64057731057763], [-23.549819091869107, -46.63560588995324], [-23.54670459977496, -46.64033633250615], [-23.55001091199737, -46.63116636914989], [-23.54532011933758, -46.64406863434122], [-23.552151883432384, -46.63080224715792], [-23.540774688874112, -46.63551484303775], [-23.5492954052167, -46.63207469510652], [-23.549009406053425, -46.64281228183975], [-23.548755593946588, -46.642789203733535], [-23.538301166801343, -46.63076391104508], [-23.54985418067981, -46.643139396906825], [-23.5471192492354, -46.634232699405686], [-23.54032130474925, -46.636394815973325], [-23.54569153926945, -46.635866061486446], [-23.54608112703553, -46.64482029837157], [-23.54874766250217, -46.64239136704376], [-23.54119147654225, -46.63499346058632], [-23.552549496537548, -46.63163152553523], [-23.55052430835593, -46.63669363835193], [-23.54239162719593, -46.63770927785183], [-23.552482452132203, -46.62938955675458], [-23.54660531805078, -46.641982174447385], [-23.54487359810152, -46.64030309449483], [-23.542908915344253, -46.63679724785041], [-23.54599881709849, -46.640834743407], [-23.54020455565808, -46.64414705704306], [-23.538670334439413, -46.62934557285476], [-23.54638197224308, -46.642893706619056], [-23.54505164917197, -46.64007245239201], [-23.540316757429707, -46.63735536871719], [-23.54639669248079, -46.64305934055624], [-23.54981334999131, -46.63035027254893], [-23.539494799586286, -46.63284391414975], [-23.539147179866543, -46.63583236462368], [-23.541700023861782, -46.64131782056096], [-23.54608112703553, -46.64482029837157], [-23.54693540437998, -46.63658792659698], [-23.54608112703553, -46.64482029837157], [-23.546774768769357, -46.64251431141433], [-23.542925000621707, -46.643423947383695], [-23.547082268784923, -46.63340844117833], [-23.547448918662464, -46.64016924063704], [-23.54532011933758, -46.64406863434122], [-23.54831797807146, -46.63542110199666], [-23.536156075768947, -46.63565005635056], [-23.547052131282804, -46.639477959749584], [-23.546453343326203, -46.63394723397195], [-23.536864121011018, -46.63349313820771], [-23.54130569969415, -46.63285261754857], [-23.54985418067981, -46.643139396906825], [-23.540774688874112, -46.63551484303775], [-23.537304315614183, -46.63386243849112], [-23.54608112703553, -46.64482029837157], [-23.54498660505508, -46.63345367485142], [-23.54425493154535, -46.634639135589296], [-23.546340513734236, -46.63623850320264], [-23.547448918662464, -46.64016924063704], [-23.547806958346342, -46.63612181853806], [-23.55253336164808, -46.62960898251487], [-23.5417

# %% [markdown]
# ##Visualizando os dados mais distribuidos no mapa

# %%
df.geolocation_state.unique( )
# Out:
# array(['SP', 'RN', 'AC', 'RJ', 'ES', 'MG', 'BA', 'SE', 'PE', 'AL', 'PB',
#        'CE', 'PI', 'MA', 'PA', 'AP', 'AM', 'RR', 'DF', 'GO', 'RO', 'TO',
#        'MT', 'MS', 'RS', 'PR', 'SC'], dtype=object)

# %%
 df.geolocation_state.value_counts()
# Out:
# geolocation_state
# SP    404268
# MG    126336
# RJ    121169
# RS     61851
# PR     57859
# SC     38328
# BA     36045
# GO     20139
# ES     16748
# PE     16432
# DF     12986
# MT     12031
# CE     11674
# PA     10853
# MS     10431
# MA      7853
# PB      5538
# RN      5041
# PI      4549
# AL      4183
# TO      3576
# SE      3563
# RO      3478
# AM      2432
# AC      1301
# AP       853
# RR       646
# Name: count, dtype: int64

# %%
df2 = df.sample(frac = 0.03)

# %%
coordenadas= []
for lat,lng in zip(df2.geolocation_lat.values, df2.geolocation_lng.values):
  coordenadas.append([lat,lng])

# %%
mapa_novo = folium.Map(location = [-15.788497, -47.879873], zoom_start = 5, tiles = 'CartoDB dark_matter')

# %%
mapa.add_child(plugins.HeatMap(coordenadas))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e8ff471b4d844689ba5b50e278b1a9b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e8ff471b4d844689ba5b50e278b1a9b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e8ff471b4d844689ba5b50e278b1a9b6 = L.map(
#                 &quot;map_e8ff471b4d844689ba5b50e278b1a9b6&quot;,
#                 {
#                     center: [-15.788497, -47.879873],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1181faebbf5dec5bb2814b497ae9e122 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1181faebbf5dec5bb2814b497ae9e122.addTo(map_e8ff471b4d844689ba5b50e278b1a9b6);
#
#
#             var heat_map_e55715735f664b1e0abdff5dd80a5426 = L.heatLayer(
#                 [[-23.54562128115268, -46.63929204800168], [-23.54608112703553, -46.64482029837157], [-23.54612896641469, -46.64295148361138], [-23.5443921648681, -46.63949930627844], [-23.541577961711493, -46.64160722329613], [-23.547762303364262, -46.63536053788448], [-23.54627311241268, -46.64122516971552], [-23.546923208436723, -46.6342636964915], [-23.543769055769133, -46.63427784085132], [-23.547639550320632, -46.63603162315495], [-23.547325128224376, -46.63418378613892], [-23.53841810407414, -46.634778375266734], [-23.546435343326205, -46.63383023397196], [-23.548945985189437, -46.63467113292871], [-23.54518734081604, -46.63785524104107], [-23.54608112703553, -46.64482029837157], [-23.54188300998332, -46.63991946670314], [-23.541389521053937, -46.62989908781218], [-23.54693540437998, -46.63658792659698], [-23.54588427921401, -46.64316319124004], [-23.545165891770928, -46.643785796266464], [-23.55223547100232, -46.6284406588955], [-23.546690486964888, -46.6354469588072], [-23.546656718016017, -46.64078762115524], [-23.549773516504185, -46.64559900666509], [-23.541593762969622, -46.64189378810082], [-23.545429533441077, -46.63571531432852], [-23.550392524842728, -46.63730164071784], [-23.5398418758395, -46.63514797691531], [-23.543539449073783, -46.64057731057763], [-23.549819091869107, -46.63560588995324], [-23.54670459977496, -46.64033633250615], [-23.55001091199737, -46.63116636914989], [-23.54532011933758, -46.64406863434122], [-23.552151883432384, -46.63080224715792], [-23.540774688874112, -46.63551484303775], [-23.5492954052167, -46.63207469510652], [-23.549009406053425, -46.64281228183975], [-23.548755593946588, -46.642789203733535], [-23.538301166801343, -46.63076391104508], [-23.54985418067981, -46.643139396906825], [-23.5471192492354, -46.634232699405686], [-23.54032130474925, -46.636394815973325], [-23.54569153926945, -46.635866061486446], [-23.54608112703553, -46.64482029837157], [-23.54874766250217, -46.64239136704376], [-23.54119147654225, -46.63499346058632], [-23.552549496537548, -46.63163152553523], [-23.55052430835593, -46.63669363835193], [-23.54239162719593, -46.63770927785183], [-23.552482452132203, -46.62938955675458], [-23.54660531805078, -46.641982174447385], [-23.54487359810152, -46.64030309449483], [-23.542908915344253, -46.63679724785041], [-23.54599881709849, -46.640834743407], [-23.54020455565808, -46.64414705704306], [-23.538670334439413, -46.62934557285476], [-23.54638197224308, -46.642893706619056], [-23.54505164917197, -46.64007245239201], [-23.540316757429707, -46.63735536871719], [-23.54639669248079, -46.64305934055624], [-23.54981334999131, -46.63035027254893], [-23.539494799586286, -46.63284391414975], [-23.539147179866543, -46.63583236462368], [-23.541700023861782, -46.64131782056096], [-23.54608112703553, -46.64482029837157], [-23.54693540437998, -46.63658792659698], [-23.54608112703553, -46.64482029837157], [-23.546774768769357, -46.64251431141433], [-23.542925000621707, -46.643423947383695], [-23.547082268784923, -46.63340844117833], [-23.547448918662464, -46.64016924063704], [-23.54532011933758, -46.64406863434122], [-23.54831797807146, -46.63542110199666], [-23.536156075768947, -46.63565005635056], [-23.547052131282804, -46.639477959749584], [-23.546453343326203, -46.63394723397195], [-23.536864121011018, -46.63349313820771], [-23.54130569969415, -46.63285261754857], [-23.54985418067981, -46.643139396906825], [-23.540774688874112, -46.63551484303775], [-23.537304315614183, -46.63386243849112], [-23.54608112703553, -46.64482029837157], [-23.54498660505508, -46.63345367485142], [-23.54425493154535, -46.634639135589296], [-23.546340513734236, -46.63623850320264], [-23.547448918662464, -46.64016924063704], [-23.547806958346342, -46.63612181853806], [-23.55253336164808, -46.62960898251487], [-23.5417

# %% [markdown]
# ##Persistindo o mapa de disco

# %%
mapa.save('mapa-consumidor.hmtl')
